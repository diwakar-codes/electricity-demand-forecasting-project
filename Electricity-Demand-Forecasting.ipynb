# %%
#importing required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
data = pd.read_csv("/Users/macbookdair/Downloads/Electricity+Demand+Dataset.csv")

# %%
data.head(5)
# Out:
#    Timestamp  hour  dayofweek  month    year  dayofyear  Temperature  \
# 0  01-Jan-20   0.0        2.0    1.0  2020.0        1.0     3.000000
# 1  01-Jan-20   1.0        2.0    1.0  2020.0        1.0     3.000000
# 2  01-Jan-20   2.0        2.0    1.0  2020.0        1.0     4.244482
# 3  01-Jan-20   3.0        2.0    1.0  2020.0        1.0     3.000000
# 4  01-Jan-20   4.0        2.0    1.0  2020.0        1.0     3.881208
#
#     Humidity       Demand
# 0  61.288951  2457.119872
# 1  52.873702  2269.904712
# 2  36.341783  2215.640403
# 3  72.629378  2174.232413
# 4  90.582444  2472.453006

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43848 entries, 0 to 43847
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Timestamp    43848 non-null  object
#  1   hour         43837 non-null  float64
#  2   dayofweek    43839 non-null  float64
#  3   month        43840 non-null  float64
#  4   year         43843 non-null  float64
#  5   dayofyear    43843 non-null  float64
#  6   Temperature  43841 non-null  float64
#  7   Humidity     43838 non-null  float64
#  8   Demand       43841 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 3.0+ MB

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'])
# Out:
# /var/folders/9n/2dw10_qs4ng4l3phmd6x41580000gn/T/ipykernel_1310/652119658.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Timestamp'] = pd.to_datetime(data['Timestamp'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43848 entries, 0 to 43847
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Timestamp    43848 non-null  datetime64[ns]
#  1   hour         43837 non-null  float64
#  2   dayofweek    43839 non-null  float64
#  3   month        43840 non-null  float64
#  4   year         43843 non-null  float64
#  5   dayofyear    43843 non-null  float64
#  6   Temperature  43841 non-null  float64
#  7   Humidity     43838 non-null  float64
#  8   Demand       43841 non-null  float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 3.0 MB

# %%
data.head(5)
# Out:
#    Timestamp  hour  dayofweek  month    year  dayofyear  Temperature  \
# 0 2020-01-01   0.0        2.0    1.0  2020.0        1.0     3.000000
# 1 2020-01-01   1.0        2.0    1.0  2020.0        1.0     3.000000
# 2 2020-01-01   2.0        2.0    1.0  2020.0        1.0     4.244482
# 3 2020-01-01   3.0        2.0    1.0  2020.0        1.0     3.000000
# 4 2020-01-01   4.0        2.0    1.0  2020.0        1.0     3.881208
#
#     Humidity       Demand
# 0  61.288951  2457.119872
# 1  52.873702  2269.904712
# 2  36.341783  2215.640403
# 3  72.629378  2174.232413
# 4  90.582444  2472.453006

# %%
data.set_index('Timestamp',inplace=True)

# %%
data.head(4)
# Out:
#             hour  dayofweek  month    year  dayofyear  Temperature   Humidity  \
# Timestamp
# 2020-01-01   0.0        2.0    1.0  2020.0        1.0     3.000000  61.288951
# 2020-01-01   1.0        2.0    1.0  2020.0        1.0     3.000000  52.873702
# 2020-01-01   2.0        2.0    1.0  2020.0        1.0     4.244482  36.341783
# 2020-01-01   3.0        2.0    1.0  2020.0        1.0     3.000000  72.629378
#
#                  Demand
# Timestamp
# 2020-01-01  2457.119872
# 2020-01-01  2269.904712
# 2020-01-01  2215.640403
# 2020-01-01  2174.232413

# %%
data[['Temperature','Humidity','Demand']].describe()
# Out:
#         Temperature      Humidity        Demand
# count  43841.000000  43838.000000  43841.000000
# mean      25.067788     59.903007   5000.790976
# std       12.821725     18.342604   1412.527409
# min        3.000000     20.000000   1611.954020
# 25%       15.210186     46.241224   4015.668472
# 50%       25.003212     59.986720   5013.053367
# 75%       34.740971     73.796820   6000.803082
# max       50.000000     95.000000  11910.705100

# %%
data.isnull().sum()
# Out:
# hour           11
# dayofweek       9
# month           8
# year            5
# dayofyear       5
# Temperature     7
# Humidity       10
# Demand          7
# dtype: int64

# %%
data[data.isna().any(axis=1)]
# Out:
#             hour  dayofweek  month    year  dayofyear  Temperature   Humidity  \
# Timestamp
# 2020-04-30   NaN        3.0    4.0  2020.0      121.0    21.820261  41.353675
# 2020-07-21   NaN        1.0    7.0  2020.0      203.0    36.555833  62.779665
# 2021-02-20   NaN        NaN    NaN     NaN        NaN          NaN        NaN
# 2021-02-20   NaN        NaN    NaN     NaN        NaN          NaN        NaN
# 2021-02-20   NaN        NaN    NaN     NaN        NaN          NaN        NaN
# 2021-02-20   NaN        NaN    NaN     NaN        NaN          NaN        NaN
# 2021-02-27   NaN        5.0    2.0  2021.0       58.0    24.001003  53.303268
# 2021-12-13  23.0        0.0   12.0  2021.0        NaN     3.000000  75.457130
# 2021-12-14   NaN        1.0   12.0  2021.0      348.0     5.061319  47.215825
# 2021-12-14  14.0        1.0   12.0  2021.0      348.0    15.403995  74.011557
# 2022-06-17  13.0        4.0    6.0  2022.0      168.0          NaN  43.171391
# ...

# %%
data[data.isna().all(axis=1)]
# Out:
#             hour  dayofweek  month  year  dayofyear  Temperature  Humidity  \
# Timestamp
# 2021-02-20   NaN        NaN    NaN   NaN        NaN          NaN       NaN
# 2021-02-20   NaN        NaN    NaN   NaN        NaN          NaN       NaN
# 2021-02-20   NaN        NaN    NaN   NaN        NaN          NaN       NaN
# 2021-02-20   NaN        NaN    NaN   NaN        NaN          NaN       NaN
#
#             Demand
# Timestamp
# 2021-02-20     NaN
# 2021-02-20     NaN
# 2021-02-20     NaN
# 2021-02-20     NaN

# %%
data.dropna(how='all',inplace=True)
data[data.isna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [hour, dayofweek, month, year, dayofyear, Temperature, Humidity, Demand]
# Index: []

# %%
data.isnull().sum()
# Out:
# hour           7
# dayofweek      5
# month          4
# year           1
# dayofyear      1
# Temperature    3
# Humidity       6
# Demand         3
# dtype: int64

# %%
#filling column values using forward and backward fill
data[['hour','dayofweek','month','year','dayofyear']] = data[['hour','dayofweek','month','year','dayofyear']].ffill()
data[['Temperature','Humidity']] = data[['Temperature','Humidity']].bfill()

# %%
data['Demand']= data['Demand'].interpolate(method='time')

# %%
data.isnull().sum()
# Out:
# hour           0
# dayofweek      0
# month          0
# year           0
# dayofyear      0
# Temperature    0
# Humidity       0
# Demand         0
# dtype: int64

# %%
data.shape
# Out:
# (43844, 8)

# %%
data
# Out:
#             hour  dayofweek  month    year  dayofyear  Temperature   Humidity  \
# Timestamp
# 2020-01-01   0.0        2.0    1.0  2020.0        1.0     3.000000  61.288951
# 2020-01-01   1.0        2.0    1.0  2020.0        1.0     3.000000  52.873702
# 2020-01-01   2.0        2.0    1.0  2020.0        1.0     4.244482  36.341783
# 2020-01-01   3.0        2.0    1.0  2020.0        1.0     3.000000  72.629378
# 2020-01-01   4.0        2.0    1.0  2020.0        1.0     3.881208  90.582444
# ...          ...        ...    ...     ...        ...          ...        ...
# 2024-12-31  19.0        1.0   12.0  2024.0      366.0     3.956838  43.287161
# 2024-12-31  20.0        1.0   12.0  2024.0      366.0     3.118824  51.705756
# 2024-12-31  21.0        1.0   12.0  2024.0      366.0     3.000000  40.565916
# 2024-12-31  22.0        1.0   12.0  2024.0      366.0     3.000000  51.998107
# 2024-12-31  23.0        1.0   12.0  2024.0      366.0     6.037472  59.931925
#
# ...

# %%
#Feature Engg
data.insert(5,'quarter',data.index.quarter)

# %%
data
# Out:
#             hour  dayofweek  month    year  dayofyear  quarter  Temperature  \
# Timestamp
# 2020-01-01   0.0        2.0    1.0  2020.0        1.0        1     3.000000
# 2020-01-01   1.0        2.0    1.0  2020.0        1.0        1     3.000000
# 2020-01-01   2.0        2.0    1.0  2020.0        1.0        1     4.244482
# 2020-01-01   3.0        2.0    1.0  2020.0        1.0        1     3.000000
# 2020-01-01   4.0        2.0    1.0  2020.0        1.0        1     3.881208
# ...          ...        ...    ...     ...        ...      ...          ...
# 2024-12-31  19.0        1.0   12.0  2024.0      366.0        4     3.956838
# 2024-12-31  20.0        1.0   12.0  2024.0      366.0        4     3.118824
# 2024-12-31  21.0        1.0   12.0  2024.0      366.0        4     3.000000
# 2024-12-31  22.0        1.0   12.0  2024.0      366.0        4     3.000000
# 2024-12-31  23.0        1.0   12.0  2024.0      366.0        4     6.037472
#
#              Humidity       Demand
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43844 entries, 2020-01-01 to 2024-12-31
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hour         43844 non-null  float64
#  1   dayofweek    43844 non-null  float64
#  2   month        43844 non-null  float64
#  3   year         43844 non-null  float64
#  4   dayofyear    43844 non-null  float64
#  5   quarter      43844 non-null  int32
#  6   Temperature  43844 non-null  float64
#  7   Humidity     43844 non-null  float64
#  8   Demand       43844 non-null  float64
# dtypes: float64(8), int32(1)
# memory usage: 3.2 MB

# %%
data[['hour','dayofweek','month','year','dayofyear']] = data[['hour','dayofweek','month','year','dayofyear']].astype(int)

# %%
data.insert(5,'weekofyear',data.index.isocalendar().week.astype(int))

# %%
data
# Out:
#             hour  dayofweek  month  year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-01     0          2      1  2020          1           1        1
# 2020-01-01     1          2      1  2020          1           1        1
# 2020-01-01     2          2      1  2020          1           1        1
# 2020-01-01     3          2      1  2020          1           1        1
# 2020-01-01     4          2      1  2020          1           1        1
# ...          ...        ...    ...   ...        ...         ...      ...
# 2024-12-31    19          1     12  2024        366           1        4
# 2024-12-31    20          1     12  2024        366           1        4
# 2024-12-31    21          1     12  2024        366           1        4
# 2024-12-31    22          1     12  2024        366           1        4
# 2024-12-31    23          1     12  2024        366           1        4
#
#             Temperature   Humidity       Demand
# Timestamp
# ...

# %%
data.tail(50)
# Out:
#             hour  dayofweek  month  year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2024-12-29    22          6     12  2024        364          52        4
# 2024-12-29    23          6     12  2024        364          52        4
# 2024-12-30     0          0     12  2024        365           1        4
# 2024-12-30     1          0     12  2024        365           1        4
# 2024-12-30     2          0     12  2024        365           1        4
# 2024-12-30     3          0     12  2024        365           1        4
# 2024-12-30     4          0     12  2024        365           1        4
# 2024-12-30     5          0     12  2024        365           1        4
# 2024-12-30     6          0     12  2024        365           1        4
# 2024-12-30     7          0     12  2024        365           1        4
# 2024-12-30     8          0     12  2024        365           1        4
# 2024-12-30     9          0     12  2024        365           1        4
# ...

# %%
data.insert(7,'is_weekend',data.index.dayofweek.isin([5,6]))

# %%
data.head
# Out:
# <bound method NDFrame.head of             hour  dayofweek  month  year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-01     0          2      1  2020          1           1        1
# 2020-01-01     1          2      1  2020          1           1        1
# 2020-01-01     2          2      1  2020          1           1        1
# 2020-01-01     3          2      1  2020          1           1        1
# 2020-01-01     4          2      1  2020          1           1        1
# ...          ...        ...    ...   ...        ...         ...      ...
# 2024-12-31    19          1     12  2024        366           1        4
# 2024-12-31    20          1     12  2024        366           1        4
# 2024-12-31    21          1     12  2024        366           1        4
# 2024-12-31    22          1     12  2024        366           1        4
# 2024-12-31    23          1     12  2024        366           1        4
#
# ...

# %%
data['is_weekend'] = data['is_weekend'].astype(int)

# %%
data[data['is_weekend']==1]
# Out:
#             hour  dayofweek  month  year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-04     0          5      1  2020          4           1        1
# 2020-01-04     1          5      1  2020          4           1        1
# 2020-01-04     2          5      1  2020          4           1        1
# 2020-01-04     3          5      1  2020          4           1        1
# 2020-01-04     4          5      1  2020          4           1        1
# ...          ...        ...    ...   ...        ...         ...      ...
# 2024-12-29    19          6     12  2024        364          52        4
# 2024-12-29    20          6     12  2024        364          52        4
# 2024-12-29    21          6     12  2024        364          52        4
# 2024-12-29    22          6     12  2024        364          52        4
# 2024-12-29    23          6     12  2024        364          52        4
#
#             is_weekend  Temperature   Humidity       Demand
# Timestamp
# ...

# %%
#Holiday package for identifying country wise holiday i.e pandas library
import holidays

# %%
data['Holidays']=holidays.IN(years = data.year)

# %%
data.head(5)
# Out:
#             hour  dayofweek  month  year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-01     0          2      1  2020          1           1        1
# 2020-01-01     1          2      1  2020          1           1        1
# 2020-01-01     2          2      1  2020          1           1        1
# 2020-01-01     3          2      1  2020          1           1        1
# 2020-01-01     4          2      1  2020          1           1        1
#
#             is_weekend  Temperature   Humidity       Demand Holidays
# Timestamp
# 2020-01-01           0     3.000000  61.288951  2457.119872      NaN
# 2020-01-01           0     3.000000  52.873702  2269.904712      NaN
# 2020-01-01           0     4.244482  36.341783  2215.640403      NaN
# 2020-01-01           0     3.000000  72.629378  2174.232413      NaN
# 2020-01-01           0     3.881208  90.582444  2472.453006      NaN

# %%
data.Holidays.value_counts()
# Out:
# Holidays
# Republic Day          120
# Maha Shivaratri       120
# Mahavir Jayanti       120
# Good Friday           120
# Buddha Purnima        120
# Id-ul-Fitr            120
# Bakrid                120
# Janmashtami           120
# Independence Day      120
# Muharram              120
# Gandhi Jayanti        120
# Dussehra              120
# Milad-un-Nabi         120
# Diwali                120
# Guru Nanak Jayanti    120
# Christmas             120
# Name: count, dtype: int64

# %%
data.drop('Holidays',axis=1,inplace=True)

# %%
data.head(2)
# Out:
#             hour  dayofweek  month  year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-01     0          2      1  2020          1           1        1
# 2020-01-01     1          2      1  2020          1           1        1
#
#             is_weekend  Temperature   Humidity       Demand
# Timestamp
# 2020-01-01           0          3.0  61.288951  2457.119872
# 2020-01-01           0          3.0  52.873702  2269.904712

# %%
#Lagged features: past values of time series data
data['Demand_lag_24hr'] = data['Demand'].shift(24)
data['Demand_lag_168hr'] = data['Demand'].shift(168)

# %%
data.head(50)
# Out:
#             hour  dayofweek  month  year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-01     0          2      1  2020          1           1        1
# 2020-01-01     1          2      1  2020          1           1        1
# 2020-01-01     2          2      1  2020          1           1        1
# 2020-01-01     3          2      1  2020          1           1        1
# 2020-01-01     4          2      1  2020          1           1        1
# 2020-01-01     5          2      1  2020          1           1        1
# 2020-01-01     6          2      1  2020          1           1        1
# 2020-01-01     7          2      1  2020          1           1        1
# 2020-01-01     8          2      1  2020          1           1        1
# 2020-01-01     9          2      1  2020          1           1        1
# 2020-01-01    10          2      1  2020          1           1        1
# 2020-01-01    11          2      1  2020          1           1        1
# ...

# %%
data.iloc[160:200]
# Out:
#             hour  dayofweek  month  year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-07    16          1      1  2020          7           2        1
# 2020-01-07    17          1      1  2020          7           2        1
# 2020-01-07    18          1      1  2020          7           2        1
# 2020-01-07    19          1      1  2020          7           2        1
# 2020-01-07    20          1      1  2020          7           2        1
# 2020-01-07    21          1      1  2020          7           2        1
# 2020-01-07    22          1      1  2020          7           2        1
# 2020-01-07    23          1      1  2020          7           2        1
# 2020-01-08     0          2      1  2020          8           2        1
# 2020-01-08     1          2      1  2020          8           2        1
# 2020-01-08     2          2      1  2020          8           2        1
# 2020-01-08     3          2      1  2020          8           2        1
# ...

# %%
#Rolling Mean & Rolling Standard Deviation
data['demand_rolling_mean_24hr'] = data['Demand'].rolling(window=24).mean()

# %%
data['demand_rolling_std_24hr'] = data['Demand'].rolling(window=24).std()

# %%
data.head(30)
# Out:
#             hour  dayofweek  month  year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-01     0          2      1  2020          1           1        1
# 2020-01-01     1          2      1  2020          1           1        1
# 2020-01-01     2          2      1  2020          1           1        1
# 2020-01-01     3          2      1  2020          1           1        1
# 2020-01-01     4          2      1  2020          1           1        1
# 2020-01-01     5          2      1  2020          1           1        1
# 2020-01-01     6          2      1  2020          1           1        1
# 2020-01-01     7          2      1  2020          1           1        1
# 2020-01-01     8          2      1  2020          1           1        1
# 2020-01-01     9          2      1  2020          1           1        1
# 2020-01-01    10          2      1  2020          1           1        1
# 2020-01-01    11          2      1  2020          1           1        1
# ...

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#             hour  dayofweek  month  year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-08     0          2      1  2020          8           2        1
# 2020-01-08     1          2      1  2020          8           2        1
# 2020-01-08     2          2      1  2020          8           2        1
# 2020-01-08     3          2      1  2020          8           2        1
# 2020-01-08     4          2      1  2020          8           2        1
# ...          ...        ...    ...   ...        ...         ...      ...
# 2024-12-31    19          1     12  2024        366           1        4
# 2024-12-31    20          1     12  2024        366           1        4
# 2024-12-31    21          1     12  2024        366           1        4
# 2024-12-31    22          1     12  2024        366           1        4
# 2024-12-31    23          1     12  2024        366           1        4
#
#             is_weekend  Temperature   Humidity       Demand  Demand_lag_24hr  \
# ...

# %%
#Visualization
data['Demand'].plot(figsize = (15,6),title = "Electricity Demand Over Time")
plt.xlabel("Year")
plt.ylabel("Demand (in MW)")
plt.show()

# %%
#visulization demand by hour of day
plt.figure(figsize = (10,6))
sns.boxplot(data = data, x = "hour", y= "Demand",color="red")
plt.title("Demand by hour of day")
plt.show()

# %%
#visulizing demand month wise
plt.figure(figsize=(10,6))
sns.boxplot(data = data,x='month',y='Demand',color="green")
plt.title("Demand by month wise")
plt.show()

# %%
#visulizing demand month wise
plt.figure(figsize=(10,6))
sns.scatterplot(data = data,x='Temperature',y='Demand',color="blue")
plt.title("Demand by Temperature wise")
plt.show()

# %%
#Correlation Matrix
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(),annot=True,fmt=".2f")
plt.title("Correlation Matrix of Features")
plt.show()
data.corr()
# Out:
#                               hour  dayofweek     month      year  dayofyear  \
# hour                      1.000000  -0.000115  0.000180  0.000102   0.000171
# dayofweek                -0.000115   1.000000  0.001075 -0.001110   0.001074
# month                     0.000180   0.001075  1.000000 -0.008866   0.996483
# year                      0.000102  -0.001110 -0.008866  1.000000  -0.009407
# dayofyear                 0.000171   0.001074  0.996483 -0.009407   1.000000
# weekofyear                0.000178   0.000205  0.971869 -0.020163   0.973509
# quarter                   0.000184   0.002582  0.971288 -0.007481   0.968174
# is_weekend               -0.000209   0.790556 -0.001224  0.000965  -0.001039
# Temperature               0.051951  -0.000997 -0.014012 -0.005114  -0.016933
# Humidity                 -0.293458  -0.002241  0.597453 -0.000723   0.596751
# Demand                    0.396138  -0.127260  0.030399  0.046548   0.028194
# ...

# %%
Y = data.Demand

# %%
X = data.drop('Demand',axis=1)

# %%
print(Y)
# Out:
# Timestamp
# 2020-01-08    2363.060115
# 2020-01-08    2282.558766
# 2020-01-08    2193.324174
# 2020-01-08    2208.724679
# 2020-01-08    2402.611018
#                  ...
# 2024-12-31    4689.693109
# 2024-12-31    4331.249224
# 2024-12-31    4015.979957
# 2024-12-31    3353.241682
# 2024-12-31    3219.023339
# Name: Demand, Length: 43676, dtype: float64

# %%
X
# Out:
#             hour  dayofweek  month  year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-08     0          2      1  2020          8           2        1
# 2020-01-08     1          2      1  2020          8           2        1
# 2020-01-08     2          2      1  2020          8           2        1
# 2020-01-08     3          2      1  2020          8           2        1
# 2020-01-08     4          2      1  2020          8           2        1
# ...          ...        ...    ...   ...        ...         ...      ...
# 2024-12-31    19          1     12  2024        366           1        4
# 2024-12-31    20          1     12  2024        366           1        4
# 2024-12-31    21          1     12  2024        366           1        4
# 2024-12-31    22          1     12  2024        366           1        4
# 2024-12-31    23          1     12  2024        366           1        4
#
#             is_weekend  Temperature   Humidity  Demand_lag_24hr  \
# Timestamp
# ...

# %%
#so the x is independent variable and is feature and Y is dependent variable which is a target
#Now splitting the data into trian and test

# %%
X_train = X.loc[:'2023-12-31']

# %%
Y_train = Y.loc[:'2023-12-31']

# %%
X_train.shape,Y_train.shape
# Out:
# ((34892, 14), (34892,))

# %%
X_test = X.loc['2024-01-01':]

# %%
Y_test = Y.loc['2024-01-01':]

# %%
X_test.shape
# Out:
# (8784, 14)

# %%
Y_test.shape
# Out:
# (8784,)

# %% [markdown]
# #XGBoost
# #It is a powerful algo used in time series forecasting.

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit

# %%
#Initializing and train the model
model_xgb = XGBRegressor(n_estimators = 1000, early_stopping_rounds = 50, learning_rate = 0.01, random_state = 42, objective = 'reg:squarederror')

# %%
model_xgb.fit(X_train,Y_train,eval_set=[(X_train,Y_train),(X_test,Y_test)],verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
#Making Prediction
prediction_xgb = model_xgb.predict(X_test)

# %%
#Evaluating the model
rmse_xgb = np.sqrt(mean_squared_error(Y_test,prediction_xgb))
mae_xgb = mean_absolute_error(Y_test,prediction_xgb)

# %%
print("XGBoost RMSE:",rmse_xgb)
print("XGBoost MAE:",mae_xgb)
# Out:
# XGBoost RMSE: 174.82216218036348
# XGBoost MAE: 123.47112975724238

# %%
#Visualizing Prediction
plt.figure(figsize = (15,6))
plt.plot(Y_test.index,Y_test,label = "Actual Demand",color = 'Blue')
plt.plot(Y_test.index,prediction_xgb,label = "Predicted values using XGBoost",color = 'red')
plt.title("XGBoost Electricity Demand Prediction")
plt.xlabel("Date")
plt.ylabel("Demand")
plt.show()

# %%
import joblib
joblib.dump(model_xgb,"electricity_xgb_prediction_model.pkl")
# Out:
# ['electricity_xgb_prediction_model.pkl']
